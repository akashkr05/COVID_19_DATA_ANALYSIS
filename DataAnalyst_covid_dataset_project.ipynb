# %% [markdown]
# # COVID DATA ANALYSIS PROJECT

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd

# %% [markdown]
# # SHOW DATASET

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\covid_19_data.csv")
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# # BASIC COMMANDS FOR ALL DATASET

# %%
print(df.count())
print()
print(df.isnull().sum())
print()
sns.heatmap(df.isnull())
print(df.corr())
df.describe()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64
#
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64
#
#            Confirmed    Deaths  Recovered
# Confirmed   1.000000  0.907294   0.596008
# Deaths      0.907294  1.000000   0.519295
# Recovered   0.596008  0.519295   1.000000
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
df.count() # it tells about all the data
df.isnull().sum() # it tells how many data is null in column
sns.heatmap(df.isnull())  # to show in graph null values
print(df.corr()) # it fetch the relation of column
df.describe()
# Out:
#            Confirmed    Deaths  Recovered
# Confirmed   1.000000  0.907294   0.596008
# Deaths      0.907294  1.000000   0.519295
# Recovered   0.596008  0.519295   1.000000
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %% [markdown]
# # Q.1 show the number of death, recovered & confirmed region cases in each region.

# %%
df.head()
df.groupby('Region')['Confirmed','Deaths','Recovered'].sum().head(50)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_21588\1187335986.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Confirmed','Deaths','Recovered'].sum().head(50)
#                           Confirmed  Deaths  Recovered
# Region
# Afghanistan                    1939      60        252
# Albania                         766      30        455
# Algeria                        3848     444       1702
# Andorra                         743      42        423
# Angola                           27       2          7
# Antigua and Barbuda              24       3         11
# Argentina                      4285     214       1192
# Armenia                        1932      30        900
# Australia                      6752      91       5715
# Austria                       15402     580      12779
# Azerbaijan                     1766      23       1267
# ...

# %%
df.head()
df.groupby('Region')['Deaths','Confirmed','Recovered'].sum().head(50)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_21588\1143452447.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Deaths','Confirmed','Recovered'].sum().head(50)
#                           Deaths  Confirmed  Recovered
# Region
# Afghanistan                   60       1939        252
# Albania                       30        766        455
# Algeria                      444       3848       1702
# Andorra                       42        743        423
# Angola                         2         27          7
# Antigua and Barbuda            3         24         11
# Argentina                    214       4285       1192
# Armenia                       30       1932        900
# Australia                     91       6752       5715
# Austria                      580      15402      12779
# Azerbaijan                    23       1766       1267
# ...

# %% [markdown]
# # Q.2 Remove all the records where the confirmed cases is less then 10.

# %%
df.head(1)
df[~(df.Confirmed<10)].head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df[(df.Confirmed<10)].head() # to show the confirmed data that is less than 10
df[~(df.Confirmed<10)].head(30) # to remove the confirmed data that is less than 10
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %%
df[(df.Confirmed<10)]
df[~(df.Confirmed<10)].head(40)
# Out:
#          Date State                    Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN               Afghanistan       1939      60        252
# 1   4/29/2020   NaN                   Albania        766      30        455
# 2   4/29/2020   NaN                   Algeria       3848     444       1702
# 3   4/29/2020   NaN                   Andorra        743      42        423
# 4   4/29/2020   NaN                    Angola         27       2          7
# 5   4/29/2020   NaN       Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN                 Argentina       4285     214       1192
# 7   4/29/2020   NaN                   Armenia       1932      30        900
# 8   4/29/2020   NaN                   Austria      15402     580      12779
# 9   4/29/2020   NaN                Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                   Bahamas         80      11         23
# ...

# %% [markdown]
# # Q.3 In which region maximum number of confirmed cases.

# %%
df.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(1)
# Out:
# Region
# US    1039909
# Name: Confirmed, dtype: int64

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\covid_19_data.csv")
df
df = df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
print(df.head(1))
# Out:
# Region
# US    1039909
# Name: Confirmed, dtype: int64

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\covid_19_data.csv")
df
df = df.groupby('Region').Confirmed.sum().sort_values(ascending=False)
print(df.head(2))
# Out:
# Region
# US       1039909
# Spain     236899
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q.4 In which region maximum number of death cases where recorded.

# %%
df.groupby('Region')['Deaths'].sum().sort_values(ascending=False).head(1)
# Out:
# Region
# US    60967
# Name: Deaths, dtype: int64

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\covid_19_data.csv")
df
df1 = df.groupby('Region').Deaths.sum().sort_values(ascending=False)
print(df1.head(5))
# Out:
# Region
# US        60967
# Italy     27682
# UK        26166
# Spain     24275
# France    24121
# Name: Deaths, dtype: int64

# %% [markdown]
# # Q.5 How many Confirmed, Death, and Recovered cases where recorded from India.

# %%
df1=df[df.Region=='India']
df1.Confirmed
df1.Deaths
df1.Recovered
# Out:
# 74    1079
# Name: Deaths, dtype: int64

# %%
print(df.head())
df.loc[df['Region']=='India']
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
df4 = df[df.Region=='India']
print(df4)
print('confirmed cases in india',df4.Confirmed.sum())
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437
# confirmed cases in india 33062

# %%
df1 = df.loc[df['Region']=='India']
print(df1)
print()
print()
confirmed = df1['Confirmed'].sum()
print("confirmed in India : ", confirmed)
print()
print()
deaths = df1['Deaths'].sum()
print("Deaths in India :", deaths)
print()
print()
recovered = df1['Recovered'].sum()
print("Recovered in India : ",recovered)
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437
#
#
# confirmed in India :  33062
#
#
# Deaths in India : 1079
#
#
# Recovered in India :  8437

# %% [markdown]
# # What is the total number of confirmed cases worldwide?

# %%
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df.Confirmed.sum()
# Out:
# 3193886

# %%
df['Confirmed'].sum()
# Out:
# 3193886

# %% [markdown]
# # What is the total number of deaths worldwide due to COVID-19?

# %%
df.Deaths.sum()
# Out:
# 227638

# %%
df['Deaths'].sum()
# Out:
# 227638

# %% [markdown]
# # Which countries have the highest number of confirmed cases and deaths?

# %%
df.nlargest(5,columns=['Confirmed','Deaths'])
# Out:
#           Date     State  Region  Confirmed  Deaths  Recovered
# 265  4/29/2020  New York      US     299691   23477          0
# 153  4/29/2020       NaN   Spain     236899   24275     132929
# 80   4/29/2020       NaN   Italy     203591   27682      71252
# 168  4/29/2020       NaN      UK     165221   26097          0
# 57   4/29/2020       NaN  France     165093   24087      48228

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\covid_19_data.csv")
df
#print(df.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(1))
print()
#print(df.groupby('Region').Deaths.sum().sort_values(ascending=False).head(1))
df1 = df.groupby('Region')['Confirmed','Deaths'].max().nlargest(5, columns=['Confirmed', 'Deaths'])
print(df1)
# Out:
#         Confirmed  Deaths
# Region
# US         299691   23477
# Spain      236899   24275
# Italy      203591   27682
# UK         165221   26097
# France     165093   24087
# C:\Users\kumar\AppData\Local\Temp\ipykernel_21588\4230935611.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = df.groupby('Region')['Confirmed','Deaths'].max().nlargest(5, columns=['Confirmed', 'Deaths'])

# %% [markdown]
# # Q.6 sort the entire data wrt number of confirmed cases in ascending order.

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\covid_19_data.csv")
df
df.Confirmed.sort_values(ascending=True)
# Out:
# 285         0
# 284         0
# 203         0
# 305         1
# 289         1
#         ...
# 57     165093
# 168    165221
# 80     203591
# 153    236899
# 265    299691
# Name: Confirmed, Length: 321, dtype: int64

# %% [markdown]
# # Q.7 sort the entire data wrt number of confirmed cases in descending order.

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\covid_19_data.csv")
df
df1 = df.sort_values('Confirmed',ascending=False)
df1.head(10)
# Out:
#           Date       State   Region  Confirmed  Deaths  Recovered
# 265  4/29/2020    New York       US     299691   23477          0
# 153  4/29/2020         NaN    Spain     236899   24275     132929
# 80   4/29/2020         NaN    Italy     203591   27682      71252
# 168  4/29/2020         NaN       UK     165221   26097          0
# 57   4/29/2020         NaN   France     165093   24087      48228
# 61   4/29/2020         NaN  Germany     161539    6467     120400
# 167  4/29/2020         NaN   Turkey     117589    3081      44040
# 262  4/29/2020  New Jersey       US     116365    6771          0
# 134  4/29/2020         NaN   Russia      99399     972      10286
# 76   4/29/2020         NaN     Iran      93657    5957      73791

# %% [markdown]
# # to find the top 5 countries with the highest number of confirmed cases in a COVID-19 dataset:

# %%
df.nlargest(5,'Confirmed')
# Out:
#           Date     State  Region  Confirmed  Deaths  Recovered
# 265  4/29/2020  New York      US     299691   23477          0
# 153  4/29/2020       NaN   Spain     236899   24275     132929
# 80   4/29/2020       NaN   Italy     203591   27682      71252
# 168  4/29/2020       NaN      UK     165221   26097          0
# 57   4/29/2020       NaN  France     165093   24087      48228

# %% [markdown]
# # convert NaN string into state name

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\covid_19_data.csv",na_values='NaN')
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]
